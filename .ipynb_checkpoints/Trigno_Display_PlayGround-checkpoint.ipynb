# %%
import sys
import numpy as np
from ConfigParser import SafeConfigParser
from argparse import ArgumentParser

# %%
sfreq = 2000
nchan = 16
nsamples = 432
byteschan = 4
minbytes = 64
perchan = 27
cols = 2
rows = nchan / cols
npt = 432*3
print(16*432*3)

# %%
old_data = np.zeros((nchan,npt))
new_data = np.zeros((nchan,npt))
print(np.shape(old_data))
print(np.shape(new_data))

# %%
print(np.shape(new_data[:,:-perchan]))
print(np.shape(old_data[:,perchan:]))

# %%
new_data[:,:-perchan] = old_data[:,perchan:]

# %%
buf = np.random.normal(1, 1, size=(432,))
print(len (buf))
print (xrange(nchan))
buf = np.random.normal(1, 1, size=(432,))

# %%
print(np.shape(new_data[1, -perchan:]))

# %%
for i in xrange(self.config.nchan):
    new_data[i, -perchan:] = buf[i:nchan * perchan:nchan]
    self.axes.flat[i].setData(self.new_data[i])
    self.old_data[:] = self.new_data[:]

# %%
buf[16:nchan * perchan:nchan]

# %%
buf[1:nchan * perchan:nchan]

# %%
data = np.random.rand(432)

# %%
print (data)
# Out:
# [  9.63507317e-01   8.01347954e-01   6.06981184e-01   9.44248763e-01
#    7.41517689e-01   6.51174186e-01   2.86311536e-01   2.31791481e-01
#    5.08009132e-01   1.92363925e-01   7.34991890e-01   4.83236861e-01
#    4.41070473e-01   9.76034855e-01   2.02700758e-01   4.58215869e-01
#    5.78645984e-01   8.84149144e-01   6.83830161e-01   4.67426265e-01
#    8.74371046e-01   3.13614228e-01   7.30539095e-01   1.81296345e-01
#    1.15002526e-01   1.20311931e-01   3.67062953e-01   9.95592977e-02
#    1.77654744e-01   8.59943866e-01   7.06863537e-01   6.83511160e-01
#    1.17664434e-01   7.39780279e-01   6.34927980e-01   4.07523393e-01
#    5.76540404e-01   6.01045612e-01   1.52099442e-01   4.15954894e-01
#    3.85778829e-01   6.29397352e-01   6.55363381e-01   6.91993986e-01
#    3.64076197e-01   8.21243206e-01   6.76800327e-01   9.76592819e-01
#    3.35957764e-01   9.29463700e-01   5.93552292e-01   4.86458482e-01
#    2.50342414e-01   2.14498999e-01   7.45329663e-01   7.46457877e-01
# ...

# %%
buf = np.reshape(data,(16,27))
B = np.reshape(data, (16,27))

# %%
print(B[1])
# Out:
# [ 0.0995593   0.17765474  0.85994387  0.70686354  0.68351116  0.11766443
#   0.73978028  0.63492798  0.40752339  0.5765404   0.60104561  0.15209944
#   0.41595489  0.38577883  0.62939735  0.65536338  0.69199399  0.3640762
#   0.82124321  0.67680033  0.97659282  0.33595776  0.9294637   0.59355229
#   0.48645848  0.25034241  0.214499  ]

# %%
9.63507317e-01   8.01347954e-01   6.06981184e-01   9.44248763e-01
   7.41517689e-01   6.51174186e-01   2.86311536e-01   2.31791481e-01
   5.08009132e-01   1.92363925e-01   7.34991890e-01   4.83236861e-01
   4.41070473e-01   9.76034855e-01   2.02700758e-01   4.58215869e-01
   5.78645984e-01   8.84149144e-01   6.83830161e-01   4.67426265e-01
   8.74371046e-01   3.13614228e-01   7.30539095e-01   1.81296345e-01
   1.15002526e-01   1.20311931e-01   3.67062953e-01
