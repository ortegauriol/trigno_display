# %%
import sys
import numpy as np
from ConfigParser import SafeConfigParser
from argparse import ArgumentParser

# %%
sfreq = 2000
nchan = 16
nsamples = 432
byteschan = 4
minbytes = 64
perchan = 27
cols = 2
rows = nchan / cols
npt = 432*3
print(16*432*3)
# Out:
# 20736

# %%
old_data = np.zeros((nchan,npt))
new_data = np.zeros((nchan,npt))
print(np.shape(old_data))
print(np.shape(new_data))
# Out:
# (16L, 1296L)
# (16L, 1296L)

# %%
print(np.shape(new_data[:,:-perchan]))
print(np.shape(old_data[:,perchan:]))
# Out:
# (16L, 1269L)
# (16L, 1269L)

# %%
new_data[:,:-perchan] = old_data[:,perchan:]

# %%
buf = np.random.normal(1, 1, size=(432,))
print(len (buf))
print (xrange(nchan))
buf = np.random.normal(1, 1, size=(432,))
# Out:
# 432
# xrange(16)

# %%
print(np.shape(new_data[1, -perchan:]))
# Out:
# (27L,)

# %%
for i in xrange(self.config.nchan):
    new_data[i, -perchan:] = buf[i:nchan * perchan:nchan]
    self.axes.flat[i].setData(self.new_data[i])
    self.old_data[:] = self.new_data[:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-2dc9f0b01c22> in <module>()
# ----> 1 for i in xrange(self.config.nchan):
#       2     self.new_data[i, -self.config.perchan:] = buf[i:self.config.nchan * self.config.perchan:self.config.nchan]
#       3     self.axes.flat[i].setData(self.new_data[i])
#       4     self.old_data[:] = self.new_data[:]
#
# NameError: name 'self' is not defined

# %%
buf[16:nchan * perchan:nchan]
# Out:
# array([ 2.82587657,  2.17226457,  1.26704965, -0.65015269, -0.29914876,
#         1.67578358,  1.05422085, -0.05499928,  1.25435154,  1.07020277,
#         1.08114481,  1.26081444,  0.79123629,  0.977129  ,  0.69203189,
#         2.02475591, -0.49929055,  2.96781759,  0.64340254,  0.84848724,
#         1.35960641,  0.56524369,  2.06948183,  3.47640596,  1.09580077,
#         0.50096905])

# %%
buf[1:nchan * perchan:nchan]
# Out:
# array([ 0.87794871,  1.16805787,  1.10586415,  0.09962073,  2.59721228,
#        -0.80291294,  2.25423344, -0.66116748,  2.47484316,  0.99446705,
#         0.55245803,  0.90022967,  0.69086253,  0.05562479,  0.68965018,
#        -0.10993076,  0.91409213,  2.69588815,  0.65165568,  1.20552888,
#        -0.16178762,  1.71760992,  2.45182243,  1.95496409,  1.18680321,
#         1.2233131 ,  1.20117   ])

# %%
print(buf)
# Out:
# [ 2.88471357  0.87794871 -0.76246308  0.59024303  1.22159304  0.51678834
#   0.7960629   0.84150808 -0.45843508  0.48745666  0.56205328  0.5779747
#   0.08371297  2.15600391  1.55875511  0.37827386  2.82587657  1.16805787
#   2.01856134  1.61951206  1.06099972 -0.52457712  0.19347697  1.11663223
